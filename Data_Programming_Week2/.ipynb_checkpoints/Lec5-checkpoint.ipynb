# %% [markdown]
# # Jupyter Notebook
#
# This is a Jupyter Notebook, which is a basically just a super fancy Python shell.
#
# You may have "cells" that can either be text (like this one) or executable Python code. Notebooks are really nice because they allow you to rapidly develop Python code by writing small bits of code, testing their output, and moving on to the next bit; this interactive nature of the notebook is a huge plus to professional Python developers.
#
# It's also nice, because it's really easy to share your code with others and surround it with text to tell a story!
#
# # Colaboratory
# Colaboratory is a service provided by Google to take a Jupyter Notebook (a standard formay of a `.ipynb` file) and let users edit/run the code in the notebook for free!
#
# This notebook is write-protected so you are not able to edit the  notebook that the whole class will look at, but you are able to open up the notebook in "playground mode" which lets you make edits to a temporary copy of the notebook. If you want to save the changes you made to this notebook, you will have to follow the instructions when you try to save to copy the notebook to your Google Drive.
#
# # Setup
# Make sure you run the following cell before trying to run any the following cells. You do not need to understand what they are doing, it's just a way to make sure there is a file we want to use stored on the computer running this notebook.

# %%
import requests

def save_file(url, file_name):
  r = requests.get(url)
  with open(file_name, 'wb') as f:
    f.write(r.content)

save_file('https://courses.cs.washington.edu/courses/cse163/19sp/' +
          'files/lectures/04-08/mobydick.txt', 'mobydick.txt')
save_file('https://courses.cs.washington.edu/courses/cse163/19sp/' +
          'files/lectures/04-08/bee-movie.txt', 'bee-movie.txt')
save_file('https://courses.cs.washington.edu/courses/cse163/19sp/' +
          'files/lectures/04-10/tas.csv', 'tas.csv')
save_file('https://courses.cs.washington.edu/courses/cse163/19sp/' +
          'files/lectures/04-10/earthquakes.csv', 'earthquakes.csv')

# %% [markdown]
# # Review

# %% [markdown]
# Last time we wrote this function to count the number of unique words that appear in a file. When we first wrote it using a list, it was way too slow on large files because the contains check for every word became incredibly slow as the list of unique words got larger. When using the new data structure set, it got much faster!

# %%
def count_unique(file_name):
  """
  Returns the number of unique words in the file specified by file_name
  """
  words = set()
  with open(file_name) as file:
    for line in file.readlines():
      for word in line.split():
        words.add(word)
  return len(words)

# %%
# %%time
print(count_unique('bee-movie.txt'))
# Out:
# 4104
# CPU times: user 4.57 ms, sys: 1.15 ms, total: 5.73 ms
# Wall time: 7.63 ms

# %%
# %%time
count_unique('mobydick.txt')
# Out:
# CPU times: user 50.6 ms, sys: 3.65 ms, total: 54.2 ms
# Wall time: 69.1 ms
# 32553

# %% [markdown]
# # Dictionaries

# %%
def count_words(file_name):
  """
  Counts the number of times each word in the file specified by file_name 
  appears in that file. Returns the counts as a dictionary with keys that
  are words that map to the number of times that word appears in the file.
  """
  counts = {}
  with open(file_name) as file:
    for line in file.readlines():
      for word in line.split():
        if word in counts:
          counts[word] = counts[word] + 1
        else: 
          counts[word] = 1
  return counts

# %%
counts = count_words('bee-movie.txt')

# %%
counts['bee']
# Out:
# 35

# %% [markdown]
# We then wanted to loop over that dictionary to find the appear the appears most frequently. We saw that there are two
# ways that this is commonly done that keep track of different variables.

# %%
max_key = None
max_value = -1  # Start at -1 so no count is the same as this first value
for word in counts.keys():
  if counts[word] > max_value:
    max_key = word
    max_value = counts[word]
    
print(max_key, max_value)
# Out:
# the 516

# %%
max_key = None
for word in counts.keys():
  if max_key is None or counts[word] > counts[max_key]:
    max_key = word

print(max_key, max_value)
# Out:
# the 516

# %% [markdown]
# # CSV

# %% [markdown]
# We learned about CSV files and how one common way of representing the data in this file is a list of dictionaries.
#
# Hunter implemented this function before lecture and briefly went over it in class. This function is NOT the import ant part of
# this example so it's safe to just understand what it's doc-string says.

# %%
def parse(file_name):
    """
    Parses the CSV file specified by file_name and returns the data as a list
    of dictionaries where each row is represented by a dictionary that
    has keys for each column and value which is the entry for that column
    at that row.
    """
    data = []
    with open(file_name) as f:
        headers = f.readline().strip().split(',')
        num_cols = len(headers)

        for line in f.readlines():
            row_data = line.strip().split(',')
            row = {}
            for i in range(num_cols):
                row[headers[i]] = row_data[i]
                #id = first_value of the row_data.
                #once we have ran thorugh each of the rows, it is going to append to the data
            data.append(row)
    return data

# %%
tas = parse('tas.csv')
tas
# Out:
# [{'Name': 'Erika', 'Salary': '3'},
#  {'Name': 'Erik', 'Salary': '2'},
#  {'Name': 'Josh', 'Salary': '4'}]

# %% [markdown]
# We then tried to run the following cell but encountered and error because the type of the data in the 'Salary' field was strings.
# All data parsed from a file is by default a string!

# %%
total = 0
for ta in tas:
  total += ta['Salary']
print(total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [12], line 3
#       1 total = 0
#       2 for ta in tas:
# ----> 3   total += ta['Salary']
#       4 print(total)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %% [markdown]
# We then went over this second function I had implemented before class to parse the data into appropriate types by taking
# extra parameters for the column names that should be converted to integers (or floats for a later example).

# %%
def parse(file_name, int_cols, float_cols):
    """
    Parses the CSV file specified by file_name and returns the data as a list
    of dictionaries where each row is represented by a dictionary that
    has keys for each column and value which is the entry for that column
    at that row.

    Also takes a list of column names that should have the data for that column
    converted to integers and a list of columns that should be converted to 
    floats. All other data will be str.
    """
    data = []
    with open(file_name) as f:
        headers = f.readline().strip().split(',')
        num_cols = len(headers)

        for line in f.readlines():
            row_data = line.strip().split(',')
            row = {}
            for i in range(num_cols):
                col = headers[i]
                if col in int_cols:
                    row[col] = int(row_data[i])
                elif col in float_cols:
                    row[col] = float(row_data[i])
                else:
                    row[col] = row_data[i]
            data.append(row)
    return data

# %%
tas = parse('tas.csv', ['Salary'], [])
tas
# Out:
# [{'Name': 'Erika', 'Salary': 3},
#  {'Name': 'Erik', 'Salary': 2},
#  {'Name': 'Josh', 'Salary': 4}]

# %%
total = 0
for ta in tas:
  total += ta['Salary']
print(total)
# Out:
# 9

# %% [markdown]
# We saw that we could then parse our other, larger, dataset using the same function

# %%
# parse the year, month, and day columns as ints and the longitude, latitude, 
# and magnitude columns as floats
earthquakes = parse('earthquakes.csv', ['year', 'month', 'day'], 
                    ['longitude', 'latitude', 'magnitude'])

# %%
earthquakes
# Out:
# [{'id': 'nc72666881',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.6723333,
#   'longitude': -121.619,
#   'name': 'California',
#   'magnitude': 1.43},
#  {'id': 'us20006i0y',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 21.5146,
#   'longitude': 94.5721,
#   'name': 'Burma',
#   'magnitude': 4.9},
#  {'id': 'nc72666891',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.5765,
#   'longitude': -118.85916670000002,
#   'name': 'California',
#   'magnitude': 0.06},
#  {'id': 'nc72666896',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.5958333,
#   'longitude': -118.99483329999998,
#   'name': 'California',
#   'magnitude': 0.4},
#  {'id': 'nn00553447',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 39.3775,
#   'longitude': -119.845,
#   'name': 'Nevada',
#   'magnitude': 0.3},
#  {'id': 'ak13805337',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.2963,
#   'longitude': -152.46,
#   'name': 'Alaska',
#   'magnitude': 1.8},
#  {'id': 'hv61354276',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 19.4235,
#   'longitude': -155.60983330000005,
#   'name': 'Hawaii',
#   'magnitude': 1.0},
#  {'id': 'ak13805339',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.3019,
#   'longitude': -152.4507,
#   'name': 'Alaska',
#   'magnitude': 2.0},
#  {'id': 'ci37640584',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.503,
#   'longitude': -118.40583329999998,
#   'name': 'California',
#   'magnitude': 1.2},
#  {'id': 'nc72666901',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.673,
#   'longitude': -121.6133333,
#   'name': 'California',
#   'magnitude': 1.67},
#  {'id': 'ci37640592',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.5888333,
#   'longitude': -116.8165,
#   'name': 'California',
#   'magnitude': 0.48},
#  {'id': 'nn00553416',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.2638,
#   'longitude': -118.7351,
#   'name': 'Nevada',
#   'magnitude': 0.9},
#  {'id': 'nc71104689',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.6811667,
#   'longitude': -121.33683329999998,
#   'name': 'California',
#   'magnitude': 0.51},
#  {'id': 'nc71104624',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.0286667,
#   'longitude': -121.19,
#   'name': 'California',
#   'magnitude': 0.53},
#  {'id': 'uu60156827',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 44.7263333,
#   'longitude': -111.2098333,
#   'name': 'Montana',
#   'magnitude': 0.14},
#  {'id': 'pr16209000',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 18.072,
#   'longitude': -66.9848,
#   'name': 'Puerto Rico',
#   'magnitude': 1.6},
#  {'id': 'ak13805345',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 51.3716,
#   'longitude': 178.7402,
#   'name': 'Alaska',
#   'magnitude': 2.1},
#  {'id': 'ci37640600',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.0758333,
#   'longitude': -117.6788333,
#   'name': 'California',
#   'magnitude': 0.73},
#  {'id': 'nc71104629',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.0263333,
#   'longitude': -121.1936667,
#   'name': 'California',
#   'magnitude': 0.22},
#  {'id': 'nc72666906',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.7763333,
#   'longitude': -122.7245,
#   'name': 'California',
#   'magnitude': 1.22},
#  {'id': 'nc72666911',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8415,
#   'longitude': -122.8288333,
#   'name': 'California',
#   'magnitude': 0.55},
#  {'id': 'hv61354336',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 19.4074993,
#   'longitude': -155.28433230000005,
#   'name': 'Hawaii',
#   'magnitude': 1.47},
#  {'id': 'ak13805346',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.5408,
#   'longitude': -149.8593,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ci37640608',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7878333,
#   'longitude': -116.037,
#   'name': 'California',
#   'magnitude': 0.81},
#  {'id': 'ak13831347',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.1835,
#   'longitude': -152.5865,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'ci37640616',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.9231667,
#   'longitude': -117.6898333,
#   'name': 'California',
#   'magnitude': 0.75},
#  {'id': 'nc72666931',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8348333,
#   'longitude': -122.8023333,
#   'name': 'California',
#   'magnitude': 1.4},
#  {'id': 'ak13805347',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.7377,
#   'longitude': -151.2365,
#   'name': 'Alaska',
#   'magnitude': 0.8},
#  {'id': 'ci37640624',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.978,
#   'longitude': -117.8535,
#   'name': 'California',
#   'magnitude': 1.13},
#  {'id': 'nc72666946',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.6363333,
#   'longitude': -118.94266670000002,
#   'name': 'California',
#   'magnitude': 0.47},
#  {'id': 'us20006i18',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -24.286,
#   'longitude': -67.8647,
#   'name': 'Chile',
#   'magnitude': 5.6},
#  {'id': 'pr16209001',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 18.6138,
#   'longitude': -68.7526,
#   'name': 'Dominican Republic',
#   'magnitude': 3.6},
#  {'id': 'ci37640640',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.9758333,
#   'longitude': -117.85966670000002,
#   'name': 'California',
#   'magnitude': 0.28},
#  {'id': 'ak13831349',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.1163,
#   'longitude': -147.2352,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ak13805706',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.0332,
#   'longitude': -151.4388,
#   'name': 'Alaska',
#   'magnitude': 2.3},
#  {'id': 'nn00553420',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.49,
#   'longitude': -113.9923,
#   'name': 'Nevada',
#   'magnitude': 1.1},
#  {'id': 'ak13831351',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.4444,
#   'longitude': -151.8699,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'us10006aa8',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 53.302,
#   'longitude': -163.5048,
#   'name': 'Alaska',
#   'magnitude': 2.5},
#  {'id': 'ak13831353',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.25100000000001,
#   'longitude': -151.3632,
#   'name': 'Alaska',
#   'magnitude': 1.3},
#  {'id': 'ak13805716',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.1521,
#   'longitude': -150.1588,
#   'name': 'Alaska',
#   'magnitude': 2.0},
#  {'id': 'nc72666956',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.7781667,
#   'longitude': -122.7505,
#   'name': 'California',
#   'magnitude': 1.75},
#  {'id': 'nc72666961',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.7885,
#   'longitude': -122.7218333,
#   'name': 'California',
#   'magnitude': 0.62},
#  {'id': 'pr16209003',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 19.3997,
#   'longitude': -64.2795,
#   'name': 'British Virgin Islands',
#   'magnitude': 2.7},
#  {'id': 'nc72666966',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.5141667,
#   'longitude': -118.8263333,
#   'name': 'California',
#   'magnitude': 0.8},
#  {'id': 'pr16209002',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 18.0625,
#   'longitude': -66.5327,
#   'name': 'Puerto Rico',
#   'magnitude': 1.8},
#  {'id': 'hv61354386',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 18.789333300000006,
#   'longitude': -154.8673333,
#   'name': 'Hawaii',
#   'magnitude': 1.83},
#  {'id': 'ak13805719',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 54.9592,
#   'longitude': -159.6299,
#   'name': 'Alaska',
#   'magnitude': 2.6},
#  {'id': 'ak13831356',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.2406,
#   'longitude': -150.5094,
#   'name': 'Alaska',
#   'magnitude': 1.3},
#  {'id': 'ci37640656',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.01716670000001,
#   'longitude': -117.81116670000002,
#   'name': 'California',
#   'magnitude': 0.06},
#  {'id': 'ci37640648',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.5145,
#   'longitude': -116.5175,
#   'name': 'California',
#   'magnitude': 0.75},
#  {'id': 'ci37640664',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 32.905,
#   'longitude': -115.5326667,
#   'name': 'California',
#   'magnitude': 1.6},
#  {'id': 'ak13806082',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.1172,
#   'longitude': -150.9111,
#   'name': 'Alaska',
#   'magnitude': 2.3},
#  {'id': 'ak13806091',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.7401,
#   'longitude': -149.2947,
#   'name': 'Alaska',
#   'magnitude': 0.3},
#  {'id': 'ak13831361',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 54.7822,
#   'longitude': -162.2961,
#   'name': 'Alaska',
#   'magnitude': 2.1},
#  {'id': 'ak13806093',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.4464,
#   'longitude': -151.7569,
#   'name': 'Alaska',
#   'magnitude': 1.1},
#  {'id': 'us20006i27',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -3.7122,
#   'longitude': 131.5537,
#   'name': 'Indonesia',
#   'magnitude': 4.9},
#  {'id': 'ak13806094',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.5351,
#   'longitude': -151.9833,
#   'name': 'Alaska',
#   'magnitude': 0.5},
#  {'id': 'ak13806095',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 68.5121,
#   'longitude': -146.7507,
#   'name': 'Alaska',
#   'magnitude': 1.0},
#  {'id': 'us100069gj',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 1.3512,
#   'longitude': 124.434,
#   'name': 'Indonesia',
#   'magnitude': 4.2},
#  {'id': 'nc72666971',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.7,
#   'longitude': -121.33816670000002,
#   'name': 'California',
#   'magnitude': 1.84},
#  {'id': 'ak13831365',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.2452,
#   'longitude': -141.1849,
#   'name': 'Alaska',
#   'magnitude': 0.9},
#  {'id': 'ak13806463',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.6271,
#   'longitude': -151.8501,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'nc72666976',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.1681667,
#   'longitude': -120.1663333,
#   'name': 'California',
#   'magnitude': 1.75},
#  {'id': 'ak13831367',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.4586,
#   'longitude': -146.6547,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ci37640696',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7398333,
#   'longitude': -117.52783329999998,
#   'name': 'California',
#   'magnitude': 0.59},
#  {'id': 'ak13806465',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.8231,
#   'longitude': -150.2247,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ci37640704',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.0166667,
#   'longitude': -116.3543333,
#   'name': 'California',
#   'magnitude': 0.84},
#  {'id': 'ak13831369',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.5179,
#   'longitude': -146.4904,
#   'name': 'Alaska',
#   'magnitude': 1.1},
#  {'id': 'nc72666986',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8160019,
#   'longitude': -122.8150024,
#   'name': 'California',
#   'magnitude': 0.71},
#  {'id': 'hv61354436',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 19.4034996,
#   'longitude': -155.2831726,
#   'name': 'Hawaii',
#   'magnitude': 2.1},
#  {'id': 'ak13831370',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.4809,
#   'longitude': -152.6624,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'ak13806467',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.2389,
#   'longitude': -151.3281,
#   'name': 'Alaska',
#   'magnitude': 0.6},
#  {'id': 'ak13831372',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 58.4244,
#   'longitude': -153.6441,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'us100067t9',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.7406,
#   'longitude': -166.6875,
#   'name': 'Alaska',
#   'magnitude': 3.3},
#  {'id': 'uw61172232',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 47.3855,
#   'longitude': -121.7835,
#   'name': 'Washington',
#   'magnitude': 1.3},
#  {'id': 'us20006i2f',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -21.7716,
#   'longitude': -113.8676,
#   'name': 'Southern East Pacific Rise',
#   'magnitude': 4.8},
#  {'id': 'ak13831374',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.8123,
#   'longitude': -147.6027,
#   'name': 'Alaska',
#   'magnitude': 1.3},
#  {'id': 'nc72666991',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.81233220000001,
#   'longitude': -122.8181686,
#   'name': 'California',
#   'magnitude': 1.02},
#  {'id': 'ak13806836',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 51.1326,
#   'longitude': 178.6078,
#   'name': 'Alaska',
#   'magnitude': 1.9},
#  {'id': 'us20006i2h',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -23.3566,
#   'longitude': -66.9895,
#   'name': 'Argentina',
#   'magnitude': 4.0},
#  {'id': 'ak13831376',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.7317,
#   'longitude': -166.6461,
#   'name': 'Alaska',
#   'magnitude': 2.3},
#  {'id': 'us20006i2i',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 10.9473,
#   'longitude': 124.6154,
#   'name': 'Philippines',
#   'magnitude': 4.9},
#  {'id': 'ak13806840',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.4966,
#   'longitude': -140.6142,
#   'name': 'Canada',
#   'magnitude': 1.1},
#  {'id': 'ci37640736',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 32.9211667,
#   'longitude': -116.2398333,
#   'name': 'California',
#   'magnitude': 1.02},
#  {'id': 'hv61354531',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 19.173,
#   'longitude': -155.5863333,
#   'name': 'Hawaii',
#   'magnitude': 1.99},
#  {'id': 'ak13831378',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 54.4634,
#   'longitude': -161.4569,
#   'name': 'Alaska',
#   'magnitude': 2.4},
#  {'id': 'nn00553474',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 39.8674,
#   'longitude': -119.0119,
#   'name': 'Nevada',
#   'magnitude': 0.8},
#  {'id': 'ci37640744',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 34.0308333,
#   'longitude': -116.7703333,
#   'name': 'California',
#   'magnitude': 1.34},
#  {'id': 'us20006i2n',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -4.8676,
#   'longitude': 153.6709,
#   'name': 'Papua New Guinea',
#   'magnitude': 4.8},
#  {'id': 'ci37640752',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7811667,
#   'longitude': -115.65533329999998,
#   'name': 'California',
#   'magnitude': 1.03},
#  {'id': 'ak13806850',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 54.1201,
#   'longitude': -161.2719,
#   'name': 'Alaska',
#   'magnitude': 3.2},
#  {'id': 'nc72667001',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.4285,
#   'longitude': -121.7716667,
#   'name': 'California',
#   'magnitude': 1.22},
#  {'id': 'us20006i2p',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.9805,
#   'longitude': 69.1573,
#   'name': 'Afghanistan',
#   'magnitude': 4.5},
#  {'id': 'nn00553426',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.6459,
#   'longitude': -118.7994,
#   'name': 'Nevada',
#   'magnitude': 2.0},
#  {'id': 'ak13831380',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.8542,
#   'longitude': -150.8216,
#   'name': 'Alaska',
#   'magnitude': 1.0},
#  {'id': 'nc72667006',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.9155,
#   'longitude': -122.8926667,
#   'name': 'California',
#   'magnitude': 1.74},
#  {'id': 'ak13807229',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 56.444,
#   'longitude': -158.9668,
#   'name': 'Alaska',
#   'magnitude': 2.0},
#  {'id': 'ci37640768',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 34.018,
#   'longitude': -116.94483329999998,
#   'name': 'California',
#   'magnitude': 1.53},
#  {'id': 'ci37640776',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.0133333,
#   'longitude': -116.3573333,
#   'name': 'California',
#   'magnitude': 1.82},
#  {'id': 'us20006i2u',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -24.1725,
#   'longitude': -67.2739,
#   'name': 'Argentina',
#   'magnitude': 4.1},
#  {'id': 'ak13831382',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.45,
#   'longitude': -140.6041,
#   'name': 'Alaska',
#   'magnitude': 0.9},
#  {'id': 'nn00553442',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 41.8767,
#   'longitude': -119.6278,
#   'name': 'Oregon',
#   'magnitude': 1.6},
#  {'id': 'uw61172252',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 45.3598333,
#   'longitude': -121.7006667,
#   'name': 'Oregon',
#   'magnitude': 0.52},
#  {'id': 'us100069gp',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -52.1331,
#   'longitude': 27.7175,
#   'name': 'South of Africa',
#   'magnitude': 4.5},
#  {'id': 'ci37640792',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.0255,
#   'longitude': -117.7645,
#   'name': 'California',
#   'magnitude': 0.61},
#  {'id': 'ak13807238',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.6281,
#   'longitude': -147.7578,
#   'name': 'Alaska',
#   'magnitude': 0.4},
#  {'id': 'nc72667016',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.646,
#   'longitude': -121.26116670000002,
#   'name': 'California',
#   'magnitude': 2.09},
#  {'id': 'nc72667021',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8293333,
#   'longitude': -122.8135,
#   'name': 'California',
#   'magnitude': 1.16},
#  {'id': 'us20006i31',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 55.1608,
#   'longitude': -159.3778,
#   'name': 'Alaska',
#   'magnitude': 3.6},
#  {'id': 'ci37640816',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.02433329999999,
#   'longitude': -117.7675,
#   'name': 'California',
#   'magnitude': 0.72},
#  {'id': 'ci37640824',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.02733329999999,
#   'longitude': -117.7651667,
#   'name': 'California',
#   'magnitude': 0.96},
#  {'id': 'us20006i32',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -7.237,
#   'longitude': -76.2101,
#   'name': 'Peru',
#   'magnitude': 4.3},
#  {'id': 'us100069gq',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -19.3536,
#   'longitude': -177.4688,
#   'name': 'Fiji',
#   'magnitude': 4.4},
#  {'id': 'ak13831385',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.7753,
#   'longitude': -136.57,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'us20006i35',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.4922,
#   'longitude': 140.7568,
#   'name': 'Japan',
#   'magnitude': 5.3},
#  {'id': 'nc72667036',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.9195,
#   'longitude': -122.8885,
#   'name': 'California',
#   'magnitude': 1.11},
#  {'id': 'ak13807656',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.1606,
#   'longitude': -153.2248,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'nc72667046',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.4673333,
#   'longitude': -118.8923333,
#   'name': 'California',
#   'magnitude': 0.65},
#  {'id': 'us20006i3b',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.8525,
#   'longitude': -97.2357,
#   'name': 'Oklahoma',
#   'magnitude': 2.6},
#  {'id': 'ak13831387',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.7552,
#   'longitude': -166.7771,
#   'name': 'Alaska',
#   'magnitude': 2.2},
#  {'id': 'ak13808047',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 67.6877,
#   'longitude': -166.7916,
#   'name': 'Alaska',
#   'magnitude': 3.0},
#  {'id': 'ak13808051',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.9393,
#   'longitude': -148.3064,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ak13831390',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.7361,
#   'longitude': -168.6086,
#   'name': 'Alaska',
#   'magnitude': 1.8},
#  {'id': 'ak13831391',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 53.9955,
#   'longitude': -163.6187,
#   'name': 'Alaska',
#   'magnitude': 2.0},
#  {'id': 'ak13808060',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.5851,
#   'longitude': -147.3953,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ak13808062',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.5873,
#   'longitude': -151.1715,
#   'name': 'Alaska',
#   'magnitude': 0.5},
#  {'id': 'ak13808063',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.205,
#   'longitude': -140.9321,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'nc72667051',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8226667,
#   'longitude': -122.84466670000002,
#   'name': 'California',
#   'magnitude': 1.56},
#  {'id': 'ak13808065',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 65.0745,
#   'longitude': -149.7254,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ci37640856',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7266667,
#   'longitude': -115.9446667,
#   'name': 'California',
#   'magnitude': 2.17},
#  {'id': 'ak13808077',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.5137,
#   'longitude': -151.2119,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'ci37640864',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.5185,
#   'longitude': -116.5193333,
#   'name': 'California',
#   'magnitude': 0.68},
#  {'id': 'ak13831397',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.9464,
#   'longitude': -152.8283,
#   'name': 'Alaska',
#   'magnitude': 1.4},
#  {'id': 'ak13808084',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.6442,
#   'longitude': -149.3513,
#   'name': 'Alaska',
#   'magnitude': 0.4},
#  {'id': 'nc72667056',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.4063333,
#   'longitude': -120.2075,
#   'name': 'California',
#   'magnitude': 2.25},
#  {'id': 'uw61172322',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 46.433,
#   'longitude': -122.3106667,
#   'name': 'Washington',
#   'magnitude': 1.33},
#  {'id': 'ak13808483',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.6092,
#   'longitude': -147.5036,
#   'name': 'Alaska',
#   'magnitude': 0.7},
#  {'id': 'us20006i5j',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.8519,
#   'longitude': -97.2366,
#   'name': 'Oklahoma',
#   'magnitude': 2.7},
#  {'id': 'ci37640896',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.9368333,
#   'longitude': -116.73633329999998,
#   'name': 'California',
#   'magnitude': 2.03},
#  {'id': 'ak13808484',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 66.3658,
#   'longitude': -150.1971,
#   'name': 'Alaska',
#   'magnitude': 1.4},
#  {'id': 'ci37640904',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7276667,
#   'longitude': -115.9425,
#   'name': 'California',
#   'magnitude': 1.28},
#  {'id': 'ak13831401',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.7041,
#   'longitude': -168.5775,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'ak13831402',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 58.8044,
#   'longitude': -155.0242,
#   'name': 'Alaska',
#   'magnitude': 2.1},
#  {'id': 'ci37640936',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.4063333,
#   'longitude': -116.3943333,
#   'name': 'California',
#   'magnitude': 0.71},
#  {'id': 'ci37640944',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7288333,
#   'longitude': -115.94433329999998,
#   'name': 'California',
#   'magnitude': 1.59},
#  {'id': 'ak13808499',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.9836,
#   'longitude': -147.3588,
#   'name': 'Alaska',
#   'magnitude': 1.0},
#  {'id': 'ci37640960',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 34.161333299999995,
#   'longitude': -116.80866670000002,
#   'name': 'California',
#   'magnitude': 2.62},
#  {'id': 'ak13808896',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.5895,
#   'longitude': -147.3766,
#   'name': 'Alaska',
#   'magnitude': 0.8},
#  {'id': 'ak13808898',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.174,
#   'longitude': -150.8544,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'uw61172332',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 48.2676667,
#   'longitude': -122.7643333,
#   'name': 'Washington',
#   'magnitude': 1.62},
#  {'id': 'ak13831406',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.6252,
#   'longitude': -166.8396,
#   'name': 'Alaska',
#   'magnitude': 2.2},
#  {'id': 'nn00553525',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 39.4179,
#   'longitude': -119.9274,
#   'name': 'Nevada',
#   'magnitude': 0.6},
#  {'id': 'ak13808899',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.3396,
#   'longitude': -153.2587,
#   'name': 'Alaska',
#   'magnitude': 0.7},
#  {'id': 'ak13808917',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.8063,
#   'longitude': -166.7396,
#   'name': 'Alaska',
#   'magnitude': 2.0},
#  {'id': 'ak13808919',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 58.4749,
#   'longitude': -154.4359,
#   'name': 'Alaska',
#   'magnitude': 1.3},
#  {'id': 'ak13808958',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.5164,
#   'longitude': -147.773,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'ci37640976',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.6343333,
#   'longitude': -116.6635,
#   'name': 'California',
#   'magnitude': 0.4},
#  {'id': 'ci37640992',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 34.3563333,
#   'longitude': -117.0238333,
#   'name': 'California',
#   'magnitude': 1.59},
#  {'id': 'ak13831411',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 55.1878,
#   'longitude': -159.5203,
#   'name': 'Alaska',
#   'magnitude': 1.8},
#  {'id': 'mb80163444',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 46.0183333,
#   'longitude': -112.4775,
#   'name': 'Montana',
#   'magnitude': 2.94},
#  {'id': 'ak13831412',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.0793,
#   'longitude': -152.2331,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'ak13808979',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.2799,
#   'longitude': -152.3027,
#   'name': 'Alaska',
#   'magnitude': 2.9},
#  {'id': 'ci37641016',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.8495,
#   'longitude': -117.4875,
#   'name': 'California',
#   'magnitude': 1.36},
#  {'id': 'nc72667096',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.7406667,
#   'longitude': -121.438,
#   'name': 'California',
#   'magnitude': 1.84},
#  {'id': 'pr16209004',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 18.9866,
#   'longitude': -65.2505,
#   'name': 'Puerto Rico',
#   'magnitude': 2.7},
#  {'id': 'ak13831414',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.5918,
#   'longitude': -166.5903,
#   'name': 'Alaska',
#   'magnitude': 2.1},
#  {'id': 'ci37641032',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7351667,
#   'longitude': -115.94866670000002,
#   'name': 'California',
#   'magnitude': 1.02},
#  {'id': 'nc72667106',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.5753333,
#   'longitude': -118.8585,
#   'name': 'California',
#   'magnitude': 0.75},
#  {'id': 'ak13831415',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.6867,
#   'longitude': -151.3328,
#   'name': 'Alaska',
#   'magnitude': 1.4},
#  {'id': 'ci37641064',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.0581667,
#   'longitude': -118.3453333,
#   'name': 'California',
#   'magnitude': 0.9},
#  {'id': 'ak13809431',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.2885,
#   'longitude': -149.3678,
#   'name': 'Alaska',
#   'magnitude': 1.0},
#  {'id': 'ak13831417',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 58.2784,
#   'longitude': -151.2473,
#   'name': 'Alaska',
#   'magnitude': 1.8},
#  {'id': 'ak13809853',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 67.3656,
#   'longitude': -149.9578,
#   'name': 'Alaska',
#   'magnitude': 0.9},
#  {'id': 'ak13809854',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.3078,
#   'longitude': -152.4596,
#   'name': 'Alaska',
#   'magnitude': 2.0},
#  {'id': 'ak13831420',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.3199,
#   'longitude': -152.5167,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'ak13831421',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.3148,
#   'longitude': -152.5359,
#   'name': 'Alaska',
#   'magnitude': 1.0},
#  {'id': 'ak13809857',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.2971,
#   'longitude': -152.4237,
#   'name': 'Alaska',
#   'magnitude': 1.4},
#  {'id': 'ak13831423',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.7724,
#   'longitude': -168.6702,
#   'name': 'Alaska',
#   'magnitude': 1.8},
#  {'id': 'ak13809859',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.5041,
#   'longitude': -147.4457,
#   'name': 'Alaska',
#   'magnitude': 1.3},
#  {'id': 'uw61172422',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 46.2615,
#   'longitude': -122.20333329999998,
#   'name': 'Washington',
#   'magnitude': 0.51},
#  {'id': 'ak13809862',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.0448,
#   'longitude': -148.3254,
#   'name': 'Alaska',
#   'magnitude': 1.9},
#  {'id': 'ak13809864',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.556,
#   'longitude': -153.5477,
#   'name': 'Alaska',
#   'magnitude': 2.5},
#  {'id': 'ak13809870',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.8328,
#   'longitude': -149.0904,
#   'name': 'Alaska',
#   'magnitude': 0.9},
#  {'id': 'uw61172437',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 45.9655,
#   'longitude': -122.629,
#   'name': 'Washington',
#   'magnitude': 1.03},
#  {'id': 'ak13809873',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.7836,
#   'longitude': -147.2442,
#   'name': 'Alaska',
#   'magnitude': 0.2},
#  {'id': 'uw61172452',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 47.355,
#   'longitude': -119.2785,
#   'name': 'Washington',
#   'magnitude': 1.49},
#  {'id': 'uw61172457',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 46.606,
#   'longitude': -119.83983329999998,
#   'name': 'Washington',
#   'magnitude': 0.99},
#  {'id': 'ci37641112',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.6805,
#   'longitude': -116.8106667,
#   'name': 'California',
#   'magnitude': 0.68},
#  {'id': 'ci37641120',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.0428333,
#   'longitude': -114.9765,
#   'name': 'Mexico',
#   'magnitude': 1.15},
#  {'id': 'uw61172462',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 46.2443333,
#   'longitude': -123.1063333,
#   'name': 'Washington',
#   'magnitude': 1.36},
#  {'id': 'ak13810299',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.8735,
#   'longitude': -148.1367,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'ci37641128',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.5331667,
#   'longitude': -117.4345,
#   'name': 'California',
#   'magnitude': 0.89},
#  {'id': 'uw61172467',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 47.1195,
#   'longitude': -120.7686667,
#   'name': 'Washington',
#   'magnitude': 1.46},
#  {'id': 'us100069h3',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -5.9001,
#   'longitude': 145.8818,
#   'name': 'Papua New Guinea',
#   'magnitude': 4.2},
#  {'id': 'ak13831430',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 53.0238,
#   'longitude': -167.2729,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'ak13810305',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.947,
#   'longitude': -148.7739,
#   'name': 'Alaska',
#   'magnitude': 1.0},
#  {'id': 'uu60156892',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 44.72866670000001,
#   'longitude': -111.2005,
#   'name': 'Montana',
#   'magnitude': 1.24},
#  {'id': 'ak13810729',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 58.4159,
#   'longitude': -154.7655,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'ak13810820',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.5541,
#   'longitude': -147.3938,
#   'name': 'Alaska',
#   'magnitude': 0.9},
#  {'id': 'ak13810819',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.1827,
#   'longitude': -152.2379,
#   'name': 'Alaska',
#   'magnitude': 1.1},
#  {'id': 'uw61172487',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 48.0113333,
#   'longitude': -119.8786667,
#   'name': 'Washington',
#   'magnitude': 1.87},
#  {'id': 'uw61172492',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 49.425,
#   'longitude': -120.523,
#   'name': 'Canada',
#   'magnitude': 1.94},
#  {'id': 'nc72667156',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 40.2971667,
#   'longitude': -124.5011667,
#   'name': 'California',
#   'magnitude': 2.5},
#  {'id': 'us100067wm',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 39.4543,
#   'longitude': 73.3421,
#   'name': 'Kyrgyzstan',
#   'magnitude': 4.6},
#  {'id': 'ci37641144',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.038000000000004,
#   'longitude': -117.6803333,
#   'name': 'California',
#   'magnitude': 1.82},
#  {'id': 'nm60152891',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.1005,
#   'longitude': -89.426,
#   'name': 'Tennessee',
#   'magnitude': 1.88},
#  {'id': 'ak13810828',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 63.8442,
#   'longitude': -148.78799999999995,
#   'name': 'Alaska',
#   'magnitude': 0.7},
#  {'id': 'ak13831436',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 54.9465,
#   'longitude': -160.3859,
#   'name': 'Alaska',
#   'magnitude': 2.1},
#  {'id': 'ak13810834',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.7299,
#   'longitude': -146.7726,
#   'name': 'Alaska',
#   'magnitude': 0.6},
#  {'id': 'ci37641160',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.7748333,
#   'longitude': -117.44866670000002,
#   'name': 'California',
#   'magnitude': 0.97},
#  {'id': 'us100067x9',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -15.4456,
#   'longitude': -173.1647,
#   'name': 'Tonga',
#   'magnitude': 4.8},
#  {'id': 'ci37641168',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.0303333,
#   'longitude': -117.775,
#   'name': 'California',
#   'magnitude': 0.34},
#  {'id': 'ak13811260',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 55.4078,
#   'longitude': -158.4937,
#   'name': 'Alaska',
#   'magnitude': 2.3},
#  {'id': 'nc72667176',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8311653,
#   'longitude': -122.7736664,
#   'name': 'California',
#   'magnitude': 0.93},
#  {'id': 'nc72667181',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.2006667,
#   'longitude': -118.4,
#   'name': 'California',
#   'magnitude': 1.88},
#  {'id': 'ci37641176',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.449,
#   'longitude': -116.462,
#   'name': 'California',
#   'magnitude': 1.64},
#  {'id': 'ak13832313',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 56.8766,
#   'longitude': -156.9522,
#   'name': 'Alaska',
#   'magnitude': 2.0},
#  {'id': 'ak13811261',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 51.3507,
#   'longitude': -174.28400000000005,
#   'name': 'Alaska',
#   'magnitude': 2.3},
#  {'id': 'nm60152966',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.4215,
#   'longitude': -93.0776667,
#   'name': 'Arkansas',
#   'magnitude': 2.76},
#  {'id': 'ci37641192',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 31.1293333,
#   'longitude': -114.0478333,
#   'name': 'Mexico',
#   'magnitude': 3.08},
#  {'id': 'ci37143356',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 36.0583333,
#   'longitude': -117.879,
#   'name': 'California',
#   'magnitude': 0.65},
#  {'id': 'ak13811269',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.2068,
#   'longitude': -153.4684,
#   'name': 'Alaska',
#   'magnitude': 1.4},
#  {'id': 'us100067xj',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -30.3675,
#   'longitude': -71.6354,
#   'name': 'Chile',
#   'magnitude': 4.3},
#  {'id': 'ak13811271',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.2608,
#   'longitude': -149.8759,
#   'name': 'Alaska',
#   'magnitude': 0.6},
#  {'id': 'us100069hu',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -4.8885,
#   'longitude': 153.7064,
#   'name': 'Papua New Guinea',
#   'magnitude': 4.3},
#  {'id': 'ci37641200',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.9611667,
#   'longitude': -116.9105,
#   'name': 'California',
#   'magnitude': 0.62},
#  {'id': 'us100069i2',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': -25.9135,
#   'longitude': 178.4949,
#   'name': 'South of the Fiji Islands',
#   'magnitude': 4.4},
#  {'id': 'nc71104639',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.1026667,
#   'longitude': -121.154,
#   'name': 'California',
#   'magnitude': 0.68},
#  {'id': 'us10006bs3',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 50.7456,
#   'longitude': 174.99400000000003,
#   'name': 'Alaska',
#   'magnitude': 3.1},
#  {'id': 'ak13832318',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.8913,
#   'longitude': -152.2587,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ak13832319',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.4989,
#   'longitude': -150.7259,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'ci37641208',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.6505,
#   'longitude': -116.78216670000002,
#   'name': 'California',
#   'magnitude': 0.74},
#  {'id': 'nc72667201',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8168333,
#   'longitude': -122.817,
#   'name': 'California',
#   'magnitude': 0.23},
#  {'id': 'nn00553602',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.6668,
#   'longitude': -118.7643,
#   'name': 'Nevada',
#   'magnitude': 0.4},
#  {'id': 'ak13811707',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 60.1265,
#   'longitude': -140.9892,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'nc71104644',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.0341667,
#   'longitude': -121.19683329999998,
#   'name': 'California',
#   'magnitude': 0.49},
#  {'id': 'hv61355286',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 19.2946667,
#   'longitude': -155.0171667,
#   'name': 'Hawaii',
#   'magnitude': 1.76},
#  {'id': 'ak13811717',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.2486,
#   'longitude': -139.3301,
#   'name': 'Canada',
#   'magnitude': 1.3},
#  {'id': 'pr16210000',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 18.9834,
#   'longitude': -66.7925,
#   'name': 'Puerto Rico',
#   'magnitude': 2.8},
#  {'id': 'us100067xv',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.2297,
#   'longitude': -139.2366,
#   'name': 'Canada',
#   'magnitude': 3.7},
#  {'id': 'nc72667211',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.555,
#   'longitude': -118.9075,
#   'name': 'California',
#   'magnitude': 0.99},
#  {'id': 'ci37641224',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.9906667,
#   'longitude': -117.2443333,
#   'name': 'California',
#   'magnitude': 1.25},
#  {'id': 'ci37641232',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.6855,
#   'longitude': -116.6713333,
#   'name': 'California',
#   'magnitude': 0.71},
#  {'id': 'ak13812167',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 64.8504,
#   'longitude': -149.0505,
#   'name': 'Alaska',
#   'magnitude': 0.2},
#  {'id': 'nn00553550',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.2658,
#   'longitude': -118.7435,
#   'name': 'Nevada',
#   'magnitude': 1.7},
#  {'id': 'ak13832324',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.9332,
#   'longitude': -151.6507,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'ak13832325',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 51.1638,
#   'longitude': -179.1618,
#   'name': 'Alaska',
#   'magnitude': 1.9},
#  {'id': 'ak13832326',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 59.7084,
#   'longitude': -153.2323,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'ci37641240',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.5145,
#   'longitude': -116.4226667,
#   'name': 'California',
#   'magnitude': 1.74},
#  {'id': 'mb80163534',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 48.8751667,
#   'longitude': -112.1306667,
#   'name': 'Montana',
#   'magnitude': 2.02},
#  {'id': 'ak13832327',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 53.2254,
#   'longitude': -165.8291,
#   'name': 'Alaska',
#   'magnitude': 1.8},
#  {'id': 'nc72667221',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.7796669,
#   'longitude': -122.7241669,
#   'name': 'California',
#   'magnitude': 0.58},
#  {'id': 'ak13832328',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 58.5396,
#   'longitude': -136.9227,
#   'name': 'Alaska',
#   'magnitude': 1.9},
#  {'id': 'ak13812182',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.3426,
#   'longitude': -150.9251,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'ak13832330',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 52.8095,
#   'longitude': -166.7744,
#   'name': 'Alaska',
#   'magnitude': 2.1},
#  {'id': 'nc72667246',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.5061667,
#   'longitude': -119.0055,
#   'name': 'California',
#   'magnitude': 0.57},
#  {'id': 'ci37641256',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.5196667,
#   'longitude': -116.52133329999998,
#   'name': 'California',
#   'magnitude': 0.42},
#  {'id': 'ak13832331',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 58.6771,
#   'longitude': -152.8279,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'nn00553605',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.4176,
#   'longitude': -117.0073,
#   'name': 'Nevada',
#   'magnitude': 0.2},
#  {'id': 'ak13812185',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 51.4712,
#   'longitude': 178.8021,
#   'name': 'Alaska',
#   'magnitude': 1.8},
#  {'id': 'nn00553553',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.6923,
#   'longitude': -115.1236,
#   'name': 'Nevada',
#   'magnitude': 1.4},
#  {'id': 'ci37641264',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 35.3395,
#   'longitude': -118.006,
#   'name': 'California',
#   'magnitude': 1.13},
#  {'id': 'nc71104649',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 37.033,
#   'longitude': -121.1961667,
#   'name': 'California',
#   'magnitude': 0.5},
#  {'id': 'uw61172567',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 46.9391667,
#   'longitude': -121.9333333,
#   'name': 'Washington',
#   'magnitude': 0.24},
#  {'id': 'ci37641272',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.5131667,
#   'longitude': -116.522,
#   'name': 'California',
#   'magnitude': 0.65},
#  {'id': 'nc72667256',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.7965012,
#   'longitude': -122.7946701,
#   'name': 'California',
#   'magnitude': 0.91},
#  {'id': 'ci37641280',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 33.2523333,
#   'longitude': -116.4063333,
#   'name': 'California',
#   'magnitude': 0.93},
#  {'id': 'nc72667261',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.7944984,
#   'longitude': -122.7990036,
#   'name': 'California',
#   'magnitude': 0.94},
#  {'id': 'hv61355426',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 19.612,
#   'longitude': -155.2628333,
#   'name': 'Hawaii',
#   'magnitude': 1.54},
#  {'id': 'ak13812632',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 62.9088,
#   'longitude': -151.0824,
#   'name': 'Alaska',
#   'magnitude': 1.4},
#  {'id': 'nc72667266',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 38.8226662,
#   'longitude': -122.7796631,
#   'name': 'California',
#   'magnitude': 0.92},
#  {'id': 'ak13832335',
#   'year': 2016,
#   'month': 7,
#   'day': 27,
#   'latitude': 61.0653,
#   'longitude': -154.1183,
#   'name': 'Alaska',
#   'magnitude': 0.8},
#  {'id': 'ak13832336',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 57.7013,
#   'longitude': -155.5783,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'hv61355456',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 19.2019997,
#   'longitude': -155.41366580000005,
#   'name': 'Hawaii',
#   'magnitude': 2.12},
#  {'id': 'nc72667276',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 37.6411667,
#   'longitude': -118.9305,
#   'name': 'California',
#   'magnitude': 0.35},
#  {'id': 'ak13812636',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 63.4517,
#   'longitude': -147.82399999999996,
#   'name': 'Alaska',
#   'magnitude': 1.1},
#  {'id': 'nn00553562',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 41.8584,
#   'longitude': -119.6533,
#   'name': 'Oregon',
#   'magnitude': 1.1},
#  {'id': 'nn00553567',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 37.471,
#   'longitude': -113.9345,
#   'name': 'Utah',
#   'magnitude': 0.9},
#  {'id': 'ci37641296',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 33.7345,
#   'longitude': -115.9526667,
#   'name': 'California',
#   'magnitude': 0.84},
#  {'id': 'nn00553557',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 41.8477,
#   'longitude': -119.658,
#   'name': 'Oregon',
#   'magnitude': 2.1},
#  {'id': 'ak13812639',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 64.3928,
#   'longitude': -146.6322,
#   'name': 'Alaska',
#   'magnitude': 0.4},
#  {'id': 'ak13812640',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 61.2858,
#   'longitude': -151.6304,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'nc72667296',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 36.5923333,
#   'longitude': -121.1303333,
#   'name': 'California',
#   'magnitude': 1.13},
#  {'id': 'pr16210001',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 19.0373,
#   'longitude': -64.3435,
#   'name': 'British Virgin Islands',
#   'magnitude': 2.1},
#  {'id': 'nc72667306',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 35.5948333,
#   'longitude': -120.8835,
#   'name': 'California',
#   'magnitude': 1.18},
#  {'id': 'ak13812641',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 64.3436,
#   'longitude': -150.7385,
#   'name': 'Alaska',
#   'magnitude': 1.6},
#  {'id': 'nc72667311',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 37.4793333,
#   'longitude': -118.9851667,
#   'name': 'California',
#   'magnitude': 1.2},
#  {'id': 'ak13812646',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 60.3553,
#   'longitude': -147.7705,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'nc72667316',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 40.0425,
#   'longitude': -121.34883329999998,
#   'name': 'California',
#   'magnitude': 1.85},
#  {'id': 'ci37641392',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 33.5101667,
#   'longitude': -116.5275,
#   'name': 'California',
#   'magnitude': 2.05},
#  {'id': 'ak13832343',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 63.7026,
#   'longitude': -149.6378,
#   'name': 'Alaska',
#   'magnitude': 1.1},
#  {'id': 'ci37641400',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 33.5173333,
#   'longitude': -116.51583329999998,
#   'name': 'California',
#   'magnitude': 0.35},
#  {'id': 'ak13812648',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 59.7964,
#   'longitude': -153.0051,
#   'name': 'Alaska',
#   'magnitude': 1.9},
#  {'id': 'ci37641408',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 33.038000000000004,
#   'longitude': -116.36266670000002,
#   'name': 'California',
#   'magnitude': 1.16},
#  {'id': 'nn00553580',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 41.8456,
#   'longitude': -119.6456,
#   'name': 'Oregon',
#   'magnitude': 1.1},
#  {'id': 'ak13832345',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 52.684,
#   'longitude': -169.1817,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'us100067z6',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 42.9566,
#   'longitude': 40.8998,
#   'name': 'Georgia',
#   'magnitude': 4.2},
#  {'id': 'ci37641432',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 33.4871667,
#   'longitude': -116.9063333,
#   'name': 'California',
#   'magnitude': 1.23},
#  {'id': 'nc72667336',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 38.81900020000001,
#   'longitude': -122.7898331,
#   'name': 'California',
#   'magnitude': 1.02},
#  {'id': 'pr16210002',
#   'year': 2016,
#   'month': 7,
#   'day': 28,
#   'latitude': 18.3605,
#   'longitude': -65.02199999999999,
# ...
#   'name': 'California',
#   'magnitude': 0.49},
#  {'id': 'nc72668666',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4103333,
#   'longitude': -121.4613333,
#   'name': 'California',
#   'magnitude': 0.87},
#  {'id': 'nc72668651',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.3955,
#   'longitude': -121.4723333,
#   'name': 'California',
#   'magnitude': 1.49},
#  {'id': 'us100069ty',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 19.039,
#   'longitude': 146.0543,
#   'name': 'Northern Mariana Islands',
#   'magnitude': 4.2},
#  {'id': 'nn00553796',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.6879,
#   'longitude': -119.4573,
#   'name': 'Nevada',
#   'magnitude': 1.9},
#  {'id': 'nc72668676',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.408,
#   'longitude': -121.4595,
#   'name': 'California',
#   'magnitude': 1.4},
#  {'id': 'nc72668681',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.828,
#   'longitude': -122.7921667,
#   'name': 'California',
#   'magnitude': 0.22},
#  {'id': 'us100068pd',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 14.053,
#   'longitude': -91.4117,
#   'name': 'Guatemala',
#   'magnitude': 4.4},
#  {'id': 'nc72668696',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4063333,
#   'longitude': -121.4643333,
#   'name': 'California',
#   'magnitude': 0.39},
#  {'id': 'nc72668691',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4043333,
#   'longitude': -121.4613333,
#   'name': 'California',
#   'magnitude': 1.98},
#  {'id': 'nc72668701',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4003333,
#   'longitude': -121.4613333,
#   'name': 'California',
#   'magnitude': 0.65},
#  {'id': 'nn00553872',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 37.2887,
#   'longitude': -117.6285,
#   'name': 'Nevada',
#   'magnitude': 0.5},
#  {'id': 'nc72668706',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4066667,
#   'longitude': -121.4663333,
#   'name': 'California',
#   'magnitude': 0.54},
#  {'id': 'nc71104444',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.41016670000001,
#   'longitude': -121.45933329999998,
#   'name': 'California',
#   'magnitude': 0.3},
#  {'id': 'nc72668711',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.40566670000001,
#   'longitude': -121.4643333,
#   'name': 'California',
#   'magnitude': 0.54},
#  {'id': 'nc72668716',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.421,
#   'longitude': -121.4475,
#   'name': 'California',
#   'magnitude': 0.75},
#  {'id': 'nc72668721',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4,
#   'longitude': -121.4578333,
#   'name': 'California',
#   'magnitude': 0.44},
#  {'id': 'nc72668726',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4048333,
#   'longitude': -121.4641667,
#   'name': 'California',
#   'magnitude': 1.25},
#  {'id': 'ak13818907',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 53.9754,
#   'longitude': -163.3774,
#   'name': 'Alaska',
#   'magnitude': 2.7},
#  {'id': 'pr16212002',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 18.377,
#   'longitude': -64.9229,
#   'name': 'U.S. Virgin Islands',
#   'magnitude': 1.5},
#  {'id': 'ci37643304',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 34.5495,
#   'longitude': -118.8323333,
#   'name': 'California',
#   'magnitude': 1.28},
#  {'id': 'mb80164234',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 48.2635,
#   'longitude': -114.26283329999998,
#   'name': 'Montana',
#   'magnitude': 0.81},
#  {'id': 'ci37643312',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 34.2186667,
#   'longitude': -118.7828333,
#   'name': 'California',
#   'magnitude': 1.55},
#  {'id': 'ak13839956',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 59.7664,
#   'longitude': -153.0736,
#   'name': 'Alaska',
#   'magnitude': 1.7},
#  {'id': 'nc72668736',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4066667,
#   'longitude': -121.4561667,
#   'name': 'California',
#   'magnitude': 2.24},
#  {'id': 'nc72668741',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4033333,
#   'longitude': -121.4635,
#   'name': 'California',
#   'magnitude': 1.26},
#  {'id': 'nc72668751',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4013333,
#   'longitude': -121.474,
#   'name': 'California',
#   'magnitude': 2.22},
#  {'id': 'nc72668756',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4013333,
#   'longitude': -121.46183329999998,
#   'name': 'California',
#   'magnitude': 2.23},
#  {'id': 'ak13839957',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 59.736,
#   'longitude': -153.1338,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'nc72668766',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4048333,
#   'longitude': -121.466,
#   'name': 'California',
#   'magnitude': 0.81},
#  {'id': 'nc72668761',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4058333,
#   'longitude': -121.45633329999998,
#   'name': 'California',
#   'magnitude': 1.4},
#  {'id': 'nc72668776',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4015,
#   'longitude': -121.4568333,
#   'name': 'California',
#   'magnitude': 0.27},
#  {'id': 'nc71104494',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4393333,
#   'longitude': -121.3775,
#   'name': 'California',
#   'magnitude': 0.19},
#  {'id': 'nc72668771',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.40566670000001,
#   'longitude': -121.4651667,
#   'name': 'California',
#   'magnitude': 1.82},
#  {'id': 'nc71104489',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.405,
#   'longitude': -121.45283329999998,
#   'name': 'California',
#   'magnitude': 1.38},
#  {'id': 'nc72669965',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4165,
#   'longitude': -121.4381667,
#   'name': 'California',
#   'magnitude': 0.58},
#  {'id': 'nc71104659',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4046667,
#   'longitude': -121.4651667,
#   'name': 'California',
#   'magnitude': 0.34},
#  {'id': 'nc71104664',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4205,
#   'longitude': -121.443,
#   'name': 'California',
#   'magnitude': 0.43},
#  {'id': 'nc72668786',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4045,
#   'longitude': -121.45716670000002,
#   'name': 'California',
#   'magnitude': 0.62},
#  {'id': 'nc72668781',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.406,
#   'longitude': -121.4625,
#   'name': 'California',
#   'magnitude': 2.38},
#  {'id': 'nc72668791',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4043333,
#   'longitude': -121.45583329999998,
#   'name': 'California',
#   'magnitude': 0.54},
#  {'id': 'nc72668796',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4051667,
#   'longitude': -121.45633329999998,
#   'name': 'California',
#   'magnitude': 0.68},
#  {'id': 'nc72668801',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4123333,
#   'longitude': -121.451,
#   'name': 'California',
#   'magnitude': 0.6},
#  {'id': 'nc71104449',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.40716670000001,
#   'longitude': -121.4651667,
#   'name': 'California',
#   'magnitude': 0.39},
#  {'id': 'nc72668816',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4023333,
#   'longitude': -121.4561667,
#   'name': 'California',
#   'magnitude': 0.6},
#  {'id': 'nc72668821',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4043333,
#   'longitude': -121.4628333,
#   'name': 'California',
#   'magnitude': 1.26},
#  {'id': 'nc72668826',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4091667,
#   'longitude': -121.4628333,
#   'name': 'California',
#   'magnitude': 0.59},
#  {'id': 'nc72668831',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4058333,
#   'longitude': -121.4736667,
#   'name': 'California',
#   'magnitude': 0.83},
#  {'id': 'ak13839958',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 63.0277,
#   'longitude': -149.7004,
#   'name': 'Alaska',
#   'magnitude': 1.1},
#  {'id': 'nc72668836',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4081667,
#   'longitude': -121.4628333,
#   'name': 'California',
#   'magnitude': 0.36},
#  {'id': 'nc71104454',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4108333,
#   'longitude': -121.45716670000002,
#   'name': 'California',
#   'magnitude': 0.26},
#  {'id': 'mb80163789',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 43.0151667,
#   'longitude': -111.25,
#   'name': 'Wyoming',
#   'magnitude': 1.27},
#  {'id': 'ci37643320',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 33.538000000000004,
#   'longitude': -116.6971667,
#   'name': 'California',
#   'magnitude': 0.62},
#  {'id': 'ak13818934',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 60.7573,
#   'longitude': -149.654,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'nc72668841',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4081667,
#   'longitude': -121.46483329999998,
#   'name': 'California',
#   'magnitude': 0.4},
#  {'id': 'nn00553806',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.8429,
#   'longitude': -118.3397,
#   'name': 'Nevada',
#   'magnitude': 1.2},
#  {'id': 'ci37643336',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 33.5368333,
#   'longitude': -116.69566670000002,
#   'name': 'California',
#   'magnitude': 0.82},
#  {'id': 'us100068q1',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 36.2471,
#   'longitude': -97.6088,
#   'name': 'Oklahoma',
#   'magnitude': 2.8},
#  {'id': 'nc72668851',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.407,
#   'longitude': -121.4543333,
#   'name': 'California',
#   'magnitude': 0.43},
#  {'id': 'ak13839960',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 52.0872,
#   'longitude': -178.5881,
#   'name': 'Alaska',
#   'magnitude': 2.3},
#  {'id': 'nn00553875',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.8583,
#   'longitude': -118.3557,
#   'name': 'Nevada',
#   'magnitude': 0.1},
#  {'id': 'nc72668861',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.40566670000001,
#   'longitude': -121.4645,
#   'name': 'California',
#   'magnitude': 1.11},
#  {'id': 'us100068q4',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 35.868,
#   'longitude': 140.6708,
#   'name': 'Japan',
#   'magnitude': 4.3},
#  {'id': 'ak13839961',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 60.6197,
#   'longitude': -151.8273,
#   'name': 'Alaska',
#   'magnitude': 1.4},
#  {'id': 'nc72668866',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 37.5313333,
#   'longitude': -118.8883333,
#   'name': 'California',
#   'magnitude': 0.7},
#  {'id': 'pr16212003',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 19.0818,
#   'longitude': -64.7686,
#   'name': 'British Virgin Islands',
#   'magnitude': 2.2},
#  {'id': 'nc72668871',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4065,
#   'longitude': -121.4626667,
#   'name': 'California',
#   'magnitude': 0.35},
#  {'id': 'nc72668876',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.395,
#   'longitude': -121.4565,
#   'name': 'California',
#   'magnitude': 0.9},
#  {'id': 'ci37643360',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 33.944166700000004,
#   'longitude': -116.8475,
#   'name': 'California',
#   'magnitude': 0.33},
#  {'id': 'nc72668881',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4085,
#   'longitude': -121.4603333,
#   'name': 'California',
#   'magnitude': 0.6},
#  {'id': 'uw61173442',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 47.5823333,
#   'longitude': -122.8196667,
#   'name': 'Washington',
#   'magnitude': 0.55},
#  {'id': 'ci37643368',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 32.1845,
#   'longitude': -115.2231667,
#   'name': 'Mexico',
#   'magnitude': 2.31},
#  {'id': 'ak13839962',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 63.201,
#   'longitude': -150.3519,
#   'name': 'Alaska',
#   'magnitude': 1.2},
#  {'id': 'nc72668891',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.399,
#   'longitude': -121.4616667,
#   'name': 'California',
#   'magnitude': 0.93},
#  {'id': 'ak13818962',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 61.2572,
#   'longitude': -151.3553,
#   'name': 'Alaska',
#   'magnitude': 2.4},
#  {'id': 'nn00553877',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.3723,
#   'longitude': -118.3555,
#   'name': 'Nevada',
#   'magnitude': 0.1},
#  {'id': 'ak13818967',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 58.7883,
#   'longitude': -154.57,
#   'name': 'Alaska',
#   'magnitude': 2.6},
#  {'id': 'ak13839965',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 61.6241,
#   'longitude': -150.0134,
#   'name': 'Alaska',
#   'magnitude': 0.9},
#  {'id': 'uw61173457',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 47.2858333,
#   'longitude': -122.2896667,
#   'name': 'Washington',
#   'magnitude': 1.32},
#  {'id': 'ci37643384',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 35.2698333,
#   'longitude': -118.9393333,
#   'name': 'California',
#   'magnitude': 1.67},
#  {'id': 'nc72668906',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 37.6361667,
#   'longitude': -118.8798333,
#   'name': 'California',
#   'magnitude': 0.26},
#  {'id': 'nc72668901',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 37.6365,
#   'longitude': -118.8863333,
#   'name': 'California',
#   'magnitude': 1.37},
#  {'id': 'nn00553879',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.7248,
#   'longitude': -119.8303,
#   'name': 'Nevada',
#   'magnitude': 1.1},
#  {'id': 'pr16212004',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 18.2294,
#   'longitude': -64.9254,
#   'name': 'U.S. Virgin Islands',
#   'magnitude': 1.8},
#  {'id': 'nc72668911',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.8066673,
#   'longitude': -122.8233337,
#   'name': 'California',
#   'magnitude': 0.79},
#  {'id': 'nc72668916',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.82,
#   'longitude': -122.81,
#   'name': 'California',
#   'magnitude': 1.29},
#  {'id': 'nn00553880',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.2646,
#   'longitude': -118.7283,
#   'name': 'Nevada',
#   'magnitude': 0.1},
#  {'id': 'ak13839966',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 62.9928,
#   'longitude': -149.7272,
#   'name': 'Alaska',
#   'magnitude': 1.0},
#  {'id': 'nc72668921',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.831501,
#   'longitude': -122.856163,
#   'name': 'California',
#   'magnitude': 0.9},
#  {'id': 'uw60128008',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 45.402,
#   'longitude': -117.255,
#   'name': 'Oregon',
#   'magnitude': 2.2},
#  {'id': 'us100068qy',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 18.8029,
#   'longitude': 145.4697,
#   'name': 'Northern Mariana Islands',
#   'magnitude': 4.5},
#  {'id': 'hv61357896',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 19.4255,
#   'longitude': -155.613,
#   'name': 'Hawaii',
#   'magnitude': 1.23},
#  {'id': 'nc72668926',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.8231659,
#   'longitude': -122.779335,
#   'name': 'California',
#   'magnitude': 0.53},
#  {'id': 'nn00553889',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 38.7257,
#   'longitude': -119.8243,
#   'name': 'Nevada',
#   'magnitude': 1.0},
#  {'id': 'ak13819000',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 62.364,
#   'longitude': -151.2215,
#   'name': 'Alaska',
#   'magnitude': 1.5},
#  {'id': 'ak13839968',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 55.6338,
#   'longitude': -161.1083,
#   'name': 'Alaska',
#   'magnitude': 1.9},
#  {'id': 'nc72668936',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 40.4006667,
#   'longitude': -121.4693333,
#   'name': 'California',
#   'magnitude': 0.54},
#  {'id': 'ci37643400',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 32.7683333,
#   'longitude': -116.5793333,
#   'name': 'California',
#   'magnitude': 0.88},
#  {'id': 'nn00553810',
#   'year': 2016,
#   'month': 7,
#   'day': 30,
#   'latitude': 39.406,
#   'longitude': -119.9401,
#   'name': 'Nevada',
#   'magnitude': 0.3},
#  ...]

# %% [markdown]
# Now with this list of dictionaries, we wanted to find the earthquake with the largest magnitude

# %%
biggest_earthquake = None
for earthquake in earthquakes:
  # word: Scripts.com
  if biggest_earthquake is None or earthquake['magnitude'] > biggest_earthquake['magnitude']:
    biggest_earthquake = earthquake

print(biggest_earthquake)
# Out:
# {'id': 'us100068jg', 'year': 2016, 'month': 7, 'day': 29, 'latitude': 18.5439, 'longitude': 145.541, 'name': 'Northern Mariana Islands', 'magnitude': 7.7}

# %% [markdown]
# While this works great, it was pretty complicated! We had to do a lot of work to parse the data and while computing the values
# we wanted from the list of dictionaries was TOO bad, it still had a fair bit of code. It would be nice if there were a way to do
# this better!

# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a libary (a packaged up piece of code shared online) that specializes in processing these CSV files

# %%
import pandas as pd  # this is just syntax to "rename" the 
                     # module so we don't have to say "pandas." everywhere
data = pd.read_csv('earthquakes.csv')

# %%
data
# Out:
#               id  year  month  day   latitude   longitude        name  \
# 0     nc72666881  2016      7   27  37.672333 -121.619000  California
# 1     us20006i0y  2016      7   27  21.514600   94.572100       Burma
# 2     nc72666891  2016      7   27  37.576500 -118.859167  California
# 3     nc72666896  2016      7   27  37.595833 -118.994833  California
# 4     nn00553447  2016      7   27  39.377500 -119.845000      Nevada
# ...          ...   ...    ...  ...        ...         ...         ...
# 8389  nc72685246  2016      8   25  36.515499 -121.099831  California
# 8390  ak13879193  2016      8   25  61.498400 -149.862700      Alaska
# 8391  nc72685251  2016      8   25  38.805000 -122.821503  California
# 8392  ci37672328  2016      8   25  34.308000 -118.635333  California
# 8393  ci37672360  2016      8   25  34.119167 -116.933667  California
#
#       magnitude
# 0          1.43
# 1          4.90
# 2          0.06
# 3          0.40
# 4          0.30
# ...         ...
# 8389       2.42
# 8390       1.40
# 8391       1.06
# 8392       1.55
# 8393       0.89
#
# [8394 rows x 8 columns]

# %% [markdown]
# This returns a `DataFrame` that stores all the information about the CSV in an easy to read manner. Below, we use the `head` function on the `DataFrame` to just show the first few rows.

# %%
data.head()
# Out:
#            id  year  month  day   latitude   longitude        name  magnitude
# 0  nc72666881  2016      7   27  37.672333 -121.619000  California       1.43
# 1  us20006i0y  2016      7   27  21.514600   94.572100       Burma       4.90
# 2  nc72666891  2016      7   27  37.576500 -118.859167  California       0.06
# 3  nc72666896  2016      7   27  37.595833 -118.994833  California       0.40
# 4  nn00553447  2016      7   27  39.377500 -119.845000      Nevada       0.30

# %% [markdown]
# You can ask for a particular column of the `DataFrame` using the following syntax

# %%
data['name']
# Out:
# 0       California
# 1            Burma
# 2       California
# 3       California
# 4           Nevada
#            ...
# 8389    California
# 8390        Alaska
# 8391    California
# 8392    California
# 8393    California
# Name: name, Length: 8394, dtype: object

# %% [markdown]
# This returns a pandas `Series` which represents one dimension of a `DataFrame`. There `Series` acts like a glorified dictionary/list, but it can do so much more!

# %%
len(data)
# Out:
# 8394

# %%
type(magnitudes)
# Out:
# pandas.core.series.Series

# %%
magnitudes = data['magnitude']
print(magnitudes.max())
print(magnitudes.min())
print(magnitudes.mean())
print(magnitudes.unique())
# Out:
# 7.7
# 0.01
# 1.512941386704789
# [1.43 4.9  0.06 0.4  0.3  1.8  1.   2.   1.2  1.67 0.48 0.9  0.51 0.53
#  0.14 1.6  2.1  0.73 0.22 1.22 0.55 1.47 0.81 0.75 1.4  0.8  1.13 0.47
#  5.6  3.6  0.28 2.3  1.1  1.5  2.5  1.3  1.75 0.62 2.7  1.83 2.6  0.5
#  4.2  1.84 0.59 0.84 0.71 0.6  1.7  3.3  4.8  1.02 1.9  4.   1.99 2.4
#  1.34 1.03 3.2  4.5  1.74 1.53 1.82 4.1  0.52 0.61 2.09 1.16 0.72 0.96
#  4.3  4.4  5.3  1.11 0.65 2.2  3.   1.56 2.17 0.68 2.25 1.33 0.7  2.03
#  1.28 1.59 2.62 1.62 2.94 2.9  1.36 0.2  1.49 0.99 1.15 0.89 1.46 1.24
#  1.87 1.94 4.6  1.88 0.97 0.34 0.93 1.64 2.76 3.08 3.1  0.74 0.23 0.49
#  1.76 2.8  3.7  1.25 2.02 0.58 0.57 0.42 0.24 0.91 0.94 1.54 0.92 2.12
#  0.35 1.18 1.85 2.05 1.23 2.56 0.87 0.85 0.25 0.83 1.38 0.88 1.06 2.16
#  1.31 1.86 1.63 0.98 1.26 1.91 5.1  1.19 0.1  0.79 0.78 0.77 0.56 1.89
#  0.82 1.71 1.73 0.27 1.61 1.66 1.95 3.22 3.5  1.57 1.98 0.37 1.96 0.26
#  2.28 2.75 1.07 1.51 0.12 3.4  1.09 0.13 1.55 1.58 0.45 1.21 2.19 0.36
#  0.86 1.27 1.29 5.4  5.   0.69 3.8  2.54 1.45 4.7  1.52 0.76 1.97 2.68
#  2.66 0.01 1.35 0.44 2.33 2.39 1.17 0.54 1.44 7.7  1.79 1.93 5.2  0.41
#  1.42 0.33 1.78 2.57 0.39 2.24 2.22 2.23 0.19 0.43 2.38 2.31 1.32 1.37
#  1.68 5.7  0.38 0.67 1.65 1.08 3.37 3.19 1.69 0.15 3.24 2.67 0.03 1.72
#  2.85 0.95 0.18 2.14 2.35 1.14 2.21 1.04 5.9  0.64 0.29 0.16 2.32 2.61
#  4.03 2.15 0.31 0.63 1.12 0.66 1.01 6.1  0.04 0.05 1.77 2.18 2.07 2.13
#  1.81 3.16 2.26 5.5  1.92 3.74 1.39 2.08 2.41 2.34 3.9  1.05 2.96 4.48
#  3.99 2.01 2.49 0.09 3.31 3.17 0.32 1.48 2.36 6.2  6.3  0.17 1.41 2.45
#  3.51 3.05 0.11 2.58 2.29 3.39 2.48 2.37 2.11 0.02 2.04 2.78 3.34 0.46
#  5.09 2.99 0.21 2.65 0.08 2.06 3.84 2.74 2.59 0.07 2.44 7.2  2.52 3.41
#  2.53 3.07 3.03 2.46 3.49 2.72 3.44 2.73 2.95 2.71 2.86 3.62 3.32 2.88
#  3.43 3.54 2.63 2.77 2.47 7.4  5.8  2.55 2.42 6.   6.4  3.13 3.53 3.15
#  6.8  3.76 3.48 2.83 2.27]

# %% [markdown]
# You can also use operators to combine `Series`. These operators work "element-wise" which means they apply the operator element by element in both `Series`

# %%
data['latitude'] + data['longitude']
# Out:
# 0       -83.946667
# 1       116.086700
# 2       -81.282667
# 3       -81.399000
# 4       -80.467500
#            ...
# 8389    -84.584331
# 8390    -88.364300
# 8391    -84.016502
# 8392    -84.327333
# 8393    -82.814500
# Length: 8394, dtype: float64

# %% [markdown]
# You can also do comparisons to find all values > 5

# %%
data['magnitude'] > 5
# Out:
#               id  year  month  day  latitude  longitude  \
# 30    us20006i18  2016      7   27  -24.2860   -67.8647
# 114   us20006i35  2016      7   27   36.4922   140.7568
# 421   us1000683b  2016      7   28  -16.8242  -172.5158
# 632   us100068b1  2016      7   29    0.0756   123.4162
# 799   us100068jg  2016      7   29   18.5439   145.5410
# ...          ...   ...    ...  ...       ...        ...
# 7916  us10006g7d  2016      8   23   42.7140    13.1719
# 7926  us10006g7w  2016      8   23   42.8223    13.1257
# 8002  us10006gbf  2016      8   24   20.9192    94.5789
# 8029  us10006gf0  2016      8   24   -2.9567   100.0549
# 8303  us20006ty8  2016      8   25   30.6151   137.8462
#
#                           name  magnitude
# 30                       Chile        5.6
# 114                      Japan        5.3
# 421                      Tonga        5.1
# 632                  Indonesia        5.4
# 799   Northern Mariana Islands        7.7
# ...                        ...        ...
# 7916                     Italy        6.2
# 7926                     Italy        5.5
# 8002                     Burma        6.8
# 8029                 Indonesia        5.8
# 8303              Japan region        5.9
#
# [100 rows x 8 columns]

# %% [markdown]
# Pandas also lets you use these bool `Series` to select which rows you want to look at in a `DataFrame`

# %%
mask = data['magnitude'] > 5
data[mask].head()  # to limit the number of values printed
# Out:
#              id  year  month  day  latitude  longitude  \
# 30   us20006i18  2016      7   27  -24.2860   -67.8647
# 114  us20006i35  2016      7   27   36.4922   140.7568
# 421  us1000683b  2016      7   28  -16.8242  -172.5158
# 632  us100068b1  2016      7   29    0.0756   123.4162
# 799  us100068jg  2016      7   29   18.5439   145.5410
#
#                          name  magnitude
# 30                      Chile        5.6
# 114                     Japan        5.3
# 421                     Tonga        5.1
# 632                 Indonesia        5.4
# 799  Northern Mariana Islands        7.7

# %% [markdown]
# You can also use multiple filter conditions by combining them with logical operators. Note that these look a bit different than the normal python operators. Also parentheses really matter here!
#
# Operator | Meaning
# ---------------|---------------
# &              | and
# &#124;    | or
# ~              | not

# %%
data[(data['magnitude'] > 5) & ~(data['name'] == 'Japan')].head()
# Out:
#              id  year  month  day  latitude  longitude  \
# 30   us20006i18  2016      7   27  -24.2860   -67.8647
# 421  us1000683b  2016      7   28  -16.8242  -172.5158
# 632  us100068b1  2016      7   29    0.0756   123.4162
# 799  us100068jg  2016      7   29   18.5439   145.5410
# 835  us100068n4  2016      7   29  -20.7929   169.9542
#
#                          name  magnitude
# 30                      Chile        5.6
# 421                     Tonga        5.1
# 632                 Indonesia        5.4
# 799  Northern Mariana Islands        7.7
# 835                   Vanuatu        5.2

# %% [markdown]
# # Location
# We've seen a few different ways (access column, use bool `Series` to filter rows) to access data in a `DataFrame`. Both of these methods rely on this underlying idea of the `loc` property. In general, you use `loc` to specify the data you want with
#
# ```
# data.loc[<row indexer>, <column indexer>]
# ```

# %%
# Get one row
data.loc[1]
# Out:
# id           us20006i0y
# year               2016
# month                 7
# day                  27
# latitude        21.5146
# longitude       94.5721
# name              Burma
# magnitude           4.9
# Name: 1, dtype: object

# %%
# Get one row and one column
data.loc[1, 'name']
# Out:
# 'Burma'

# %%
# Can use lists for both! 
data.loc[[1,2,3], ['year', 'month', 'day']]
# Out:
#    year  month  day
# 1  2016      7   27
# 2  2016      7   27
# 3  2016      7   27

# %%
# Can use ranges to specify both! 
# Note: The ranges are inclusive unlike almost everywhere else in Python! 
data.loc[1:3, 'year':'day']
# Out:
#    year  month  day
# 1  2016      7   27
# 2  2016      7   27
# 3  2016      7   27
